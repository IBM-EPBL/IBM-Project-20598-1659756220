# %%
#Assignment 4 Data Analytics

# %%
#Load the dataset into the tool.

# %%
import pandas as pd

# %%
dataset= pd.read_csv('abalone.csv')
pd.value_counts(dataset['Sex'])
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
#Visualizations- Univariate Analysis

# %%
from matplotlib import pyplot as plt
univarient_name=["Male","Female","Infant"]
univar_value=[1528,1307,1342]
mycolors = ["yellow", "hotpink",  "#4CAF50"]
plt.pie(univar_value,labels=univarient_name,autopct="%2.1f%%",colors = mycolors)
plt.show()

# %%
#Visualizations - Bi-varient analysis

# %%
import seaborn as sns
sns.scatterplot(x='Whole weight',y='Rings',data=dataset)
# Out:
# <AxesSubplot:xlabel='Whole weight', ylabel='Rings'>

# %%
#Visualizations - Multivarient analysis

# %%
ds=dataset.head(10)
name=ds["Sex"]
one=ds["Whole weight"]
two=ds["Shucked weight"]
three=ds["Viscera weight"]
plt.bar(name,one,label="Whole weight",color='lightgreen')
plt.bar(name,two,label="Shucked weight",color='orange')
plt.bar(name,three,label="Viscera weight",color='purple')
plt.legend()
plt.show()

# %%
#Descriptive statistics on the dataset
dataset["Age"] = dataset["Rings"] + 1.5

# %%
dataset.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings          Age
# count     4177.000000   4177.000000  4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684    11.433684
# std          0.109614      0.139203     3.224169     3.224169
# ...

# %%
#Outlier

# %%
plt.scatter(dataset.Height,dataset.Length)

# %%
#Outlier values

# %%
import numpy as np
print(np.where(dataset['Height']>0.4))
# Out:
# (array([1417, 2051], dtype=int64),)

# %%
#dependent and independent variable

# %%
x=dataset.iloc[:,1:9]

# %%
y=dataset.iloc[:,9:10]

# %%
#Train,Test & Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (3341, 8)

# %%
x_test.shape
# Out:
# (836, 8)

# %%
y_train.shape
# Out:
# (3341, 1)

# %%
y_test.shape
# Out:
# (836, 1)

# %%
#Model Building

# %%
from sklearn.linear_model import LinearRegression 
slr=LinearRegression()
slr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
slr.predict(x_test)
# Out:
# array([[14.5],
#        [ 9.5],
#        [12.5],
#        [ 6.5],
#        [13.5],
#        [12.5],
#        [ 8.5],
#        [ 9.5],
#        [ 8.5],
#        [10.5],
#        [ 9.5],
#        [ 9.5],
#        [12.5],
#        [10.5],
#        [ 5.5],
#        [ 8.5],
#        [ 8.5],
#        [18.5],
#        [ 8.5],
#        [ 8.5],
#        [ 8.5],
#        [ 6.5],
#        [ 9.5],
#        [10.5],
#        [11.5],
#        [11.5],
#        [ 6.5],
#        [16.5],
#        [11.5],
#        [15.5],
#        [ 9.5],
#        [ 5.5],
#        [10.5],
#        [14.5],
#        [ 8.5],
#        [ 8.5],
#        [ 9.5],
#        [10.5],
#        [ 9.5],
#        [12.5],
#        [16.5],
#        [13.5],
#        [18.5],
#        [17.5],
#        [12.5],
#        [12.5],
#        [ 9.5],
#        [11.5],
#        [12.5],
#        [ 7.5],
#        [14.5],
#        [ 8.5],
#        [14.5],
#        [21.5],
#        [13.5],
#        [ 8.5],
#        [ 9.5],
#        [11.5],
# ...

# %%
#Measure the performance using Metrics

# %%
from sklearn.metrics import r2_score
r2_score(slr.predict(x_test),y_test)
# Out:
# 1.0

# %%
y_test
# Out:
#        Age
# 668   14.5
# 1580   9.5
# 3784  12.5
# 463    6.5
# 2615  13.5
# ...    ...
# 575   12.5
# 3231  13.5
# 1084   8.5
# 290   18.5
# 2713   5.5
#
# [836 rows x 1 columns]
